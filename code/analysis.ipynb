# %%
import requests
import json
import pandas as pd

# %%
nobel_url = "https://api.nobelprize.org/2.1/nobelPrizes?offset=1&limit=10000&sort=desc&nobelPrizeYear=1901&yearTo=2023&format=json"

# %%
url = "https://api.nobelprize.org/v1/prize.json"

# %%
print(requests.get(nobel_url))
# Out:
# <Response [200]>

# %%
print(requests.get(nobel_url).json())
# Out:
# {'nobelPrizes': [{'awardYear': '2023', 'category': {'en': 'Physics', 'no': 'Fysikk', 'se': 'Fysik'}, 'categoryFullName': {'en': 'The Nobel Prize in Physics', 'no': 'Nobelprisen i fysikk', 'se': 'Nobelpriset i fysik'}, 'dateAwarded': '2023-10-03', 'prizeAmount': 11000000, 'prizeAmountAdjusted': 11000000, 'links': [{'rel': 'nobelPrize', 'href': 'https://api.nobelprize.org/2/nobelPrize/phy/2023', 'action': 'GET', 'types': 'application/json'}], 'laureates': [{'id': '1026', 'knownName': {'en': 'Pierre Agostini'}, 'fullName': {'en': 'Pierre Agostini'}, 'portion': '1/3', 'sortOrder': '1', 'motivation': {'en': 'for experimental methods that generate attosecond pulses of light for the study of electron dynamics in matter', 'se': 'för experimentella metoder som genererar attosekundpulser av ljus för studier av elektrondynamik i materia'}, 'links': [{'rel': 'laureate', 'href': 'https://api.nobelprize.org/2/laureate/1026', 'action': 'GET', 'types': 'application/json'}]}, {'id': '1027', 'knownName': {'en': 'Ferenc Krausz'}, 'fullName': {'en': 'Ferenc Krausz'}, 'portion': '1/3', 'sortOrder': '2', 'motivation': {'en': 'for experimental methods that generate attosecond pulses of light for the study of electron dynamics in matter', 'se': 'för experimentella metoder som genererar attosekundpulser av ljus för studier av elektrondynamik i materia'}, 'links': [{'rel': 'laureate', 'href': 'https://api.nobelprize.org/2/laureate/1027', 'action': 'GET', 'types': 'application/json'}]}, {'id': '1028', 'knownName': {'en': 'Anne L’Huillier'}, 'fullName': {'en': 'Anne L’Huillier'}, 'portion': '1/3', 'sortOrder': '3', 'motivation': {'en': 'for experimental methods that generate attosecond pulses of light for the study of electron dynamics in matter', 'se': 'för experimentella metoder som genererar attosekundpulser av ljus för studier av elektrondynamik i materia'}, 'links': [{'rel': 'laureate', 'href': 'https://api.nobelprize.org/2/laureate/1028', 'action': 'GET', 'types': 'application/json'}]}]}, {'awardYear': '2023', 'category': {'en': 'Peace', 'no': 'Fred', 'se': 'Fred'}, 'categoryFullName': {'en': 'The Nobel Peace Prize', 'no': 'Nobels fredspris', 'se': 'Nobels fredspris'}, 'dateAwarded': '2023-10-06', 'prizeAmount': 11000000, 'prizeAmountAdjusted': 11000000, 'links': [{'rel': 'nobelPrize', 'href': 'https://api.nobelprize.org/2/nobelPrize/pea/2023', 'action': 'GET', 'types': 'application/json'}], 'laureates': [{'id': '1033', 'knownName': {'en': 'Narges Mohammadi', 'no': 'Narges Mohammadi'}, 'fullName': {'en': 'Narges Mohammadi'}, 'portion': '1', 'sortOrder': '1', 'motivation': {'en': 'for her fight against the oppression of women in Iran and her fight to promote human rights and freedom for all', 'no': 'for hennes kamp mot undertrykking av kvinner i Iran og hennes kamp for menneskerettigheter og frihet for alle'}, 'links': [{'rel': 'laureate', 'href': 'https://api.nobelprize.org/2/laureate/1033', 'action': 'GET', 'types': 'application/json'}]}]}, {'awardYear': '2023', 'category': {'en': 'Literature', 'no': 'Litteratur', 'se': 'Litteratur'}, 'categoryFullName': {'en': 'The Nobel Prize in Literature', 'no': 'Nobelprisen i litteratur', 'se': 'Nobelpriset i litteratur'}, 'dateAwarded': '2023-10-05', 'prizeAmount': 11000000, 'prizeAmountAdjusted': 11000000, 'links': [{'rel': 'nobelPrize', 'href': 'https://api.nobelprize.org/2/nobelPrize/lit/2023', 'action': 'GET', 'types': 'application/json'}], 'laureates': [{'id': '1032', 'knownName': {'en': 'Jon Fosse'}, 'fullName': {'en': 'Jon Fosse'}, 'portion': '1', 'sortOrder': '1', 'motivation': {'en': 'for his innovative plays and prose which give voice to the unsayable', 'se': 'för hans nyskapande dramatik och prosa som ger röst åt det osägbara'}, 'links': [{'rel': 'laureate', 'href': 'https://api.nobelprize.org/2/laureate/1032', 'action': 'GET', 'types': 'application/json'}]}]}, {'awardYear': '2023', 'category': {'en': 'Economic Sciences', 'no': 'Økonomi', 'se': 'Ekonomi'}, 'categoryFullName': {'en': 'The Sveriges  ...

# %%
# Pretty Print the output of the JSON

response = requests.get(nobel_url).json()
print(json.dumps(response, indent = 4, sort_keys = True))
# Out:
# {
#     "links": {
#         "first": "https://masterdataapi.nobelprize.org/2.1/nobelPrizes?offset=0&limit=10000&nobelPrizeYear=1901&yearTo=2023",
#         "last": "https://masterdataapi.nobelprize.org/2.1/nobelPrizes?offset=0&limit=10000&nobelPrizeYear=1901&yearTo=2023",
#         "self": "https://masterdataapi.nobelprize.org/2.1/nobelPrizes?offset=1&limit=10000&nobelPrizeYear=1901&yearTo=2023"
#     },
#     "meta": {
#         "count": 670,
#         "disclaimer": "https://www.nobelprize.org/about/terms-of-use-for-api-nobelprize-org-and-data-nobelprize-org/#disclaimer",
#         "license": "https://www.nobelprize.org/about/terms-of-use-for-api-nobelprize-org-and-data-nobelprize-org/#licence",
#         "limit": 10000,
#         "nobelPrizeYear": 1901,
#         "offset": 1,
#         "terms": "https://www.nobelprize.org/about/terms-of-use-for-api-nobelprize-org-and-data-nobelprize-org/",
#         "yearTo": 2023
#     },
#     "nobelPrizes": [
#         {
#             "awardYear": "2023",
#             "category": {
#                 "en": "Physics",
#                 "no": "Fysikk",
#                 "se": "Fysik"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Physics",
#                 "no": "Nobelprisen i fysikk",
#                 "se": "Nobelpriset i fysik"
#             },
#             "dateAwarded": "2023-10-03",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Pierre Agostini"
#                     },
#                     "id": "1026",
#                     "knownName": {
#                         "en": "Pierre Agostini"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1026",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for experimental methods that generate attosecond pulses of light for the study of electron dynamics in matter",
#                         "se": "f\u00f6r experimentella metoder som genererar attosekundpulser av ljus f\u00f6r studier av elektrondynamik i materia"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "1"
#                 },
#                 {
#                     "fullName": {
#                         "en": "Ferenc Krausz"
#                     },
#                     "id": "1027",
#                     "knownName": {
#                         "en": "Ferenc Krausz"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1027",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for experimental methods that generate attosecond pulses of light for the study of electron dynamics in matter",
#                         "se": "f\u00f6r experimentella metoder som genererar attosekundpulser av ljus f\u00f6r studier av elektrondynamik i materia"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "2"
#                 },
#                 {
#                     "fullName": {
#                         "en": "Anne L\u2019Huillier"
#                     },
#                     "id": "1028",
#                     "knownName": {
#                         "en": "Anne L\u2019Huillier"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1028",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for experimental methods that generate attosecond pulses of light for the study of electron dynamics in matter",
#                         "se": "f\u00f6r experimentella metoder som genererar attosekundpulser av ljus f\u00f6r studier av elektrondynamik i materia"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "3"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/phy/2023",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 11000000,
#             "prizeAmountAdjusted": 11000000
#         },
#         {
#             "awardYear": "2023",
#             "category": {
#                 "en": "Peace",
#                 "no": "Fred",
#                 "se": "Fred"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Peace Prize",
#                 "no": "Nobels fredspris",
#                 "se": "Nobels fredspris"
#             },
#             "dateAwarded": "2023-10-06",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Narges Mohammadi"
#                     },
#                     "id": "1033",
#                     "knownName": {
#                         "en": "Narges Mohammadi",
#                         "no": "Narges Mohammadi"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1033",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for her fight against the oppression of women in Iran and her fight to promote human rights and freedom for all",
#                         "no": "for hennes kamp mot undertrykking av kvinner i Iran og hennes kamp for menneskerettigheter og frihet for alle"
#                     },
#                     "portion": "1",
#                     "sortOrder": "1"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/pea/2023",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 11000000,
#             "prizeAmountAdjusted": 11000000
#         },
#         {
#             "awardYear": "2023",
#             "category": {
#                 "en": "Literature",
#                 "no": "Litteratur",
#                 "se": "Litteratur"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Literature",
#                 "no": "Nobelprisen i litteratur",
#                 "se": "Nobelpriset i litteratur"
#             },
#             "dateAwarded": "2023-10-05",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Jon Fosse"
#                     },
#                     "id": "1032",
#                     "knownName": {
#                         "en": "Jon Fosse"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1032",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for his innovative plays and prose which give voice to the unsayable",
#                         "se": "f\u00f6r hans nyskapande dramatik och prosa som ger r\u00f6st \u00e5t det os\u00e4gbara"
#                     },
#                     "portion": "1",
#                     "sortOrder": "1"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/lit/2023",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 11000000,
#             "prizeAmountAdjusted": 11000000
#         },
#         {
#             "awardYear": "2023",
#             "category": {
#                 "en": "Economic Sciences",
#                 "no": "\u00d8konomi",
#                 "se": "Ekonomi"
#             },
#             "categoryFullName": {
#                 "en": "The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel",
#                 "no": "Sveriges Riksbanks pris i \u00f8konomisk vitenskap til minne om Alfred Nobel",
#                 "se": "Sveriges Riksbanks pris i ekonomisk vetenskap till Alfred Nobels minne"
#             },
#             "dateAwarded": "2023-10-09",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Claudia Goldin"
#                     },
#                     "id": "1034",
#                     "knownName": {
#                         "en": "Claudia Goldin"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1034",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for having advanced our understanding of women\u2019s labour market outcomes",
#                         "se": "f\u00f6r att ha f\u00f6rb\u00e4ttrat v\u00e5r f\u00f6rst\u00e5else av kvinnors arbetsmarknadsutfall"
#                     },
#                     "portion": "1",
#                     "sortOrder": "1"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/eco/2023",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 11000000,
#             "prizeAmountAdjusted": 11000000
#         },
#         {
#             "awardYear": "2023",
#             "category": {
#                 "en": "Chemistry",
#                 "no": "Kjemi",
#                 "se": "Kemi"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Chemistry",
#                 "no": "Nobelprisen i kjemi",
#                 "se": "Nobelpriset i kemi"
#             },
#             "dateAwarded": "2023-10-04",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Moungi G. Bawendi"
#                     },
#                     "id": "1029",
#                     "knownName": {
#                         "en": "Moungi Bawendi"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1029",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for the discovery and synthesis of quantum dots",
#                         "se": "f\u00f6r uppt\u00e4ckt och syntes av kvantprickar"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "1"
#                 },
#                 {
#                     "fullName": {
#                         "en": "Louis E. Brus"
#                     },
#                     "id": "1030",
#                     "knownName": {
#                         "en": "Louis Brus"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1030",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for the discovery and synthesis of quantum dots",
#                         "se": "f\u00f6r uppt\u00e4ckt och syntes av kvantprickar"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "2"
#                 },
#                 {
#                     "fullName": {
#                         "en": "Aleksey Yekimov "
#                     },
#                     "id": "1031",
#                     "knownName": {
#                         "en": "Aleksey Yekimov "
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1031",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for the discovery and synthesis of quantum dots",
#                         "se": "f\u00f6r uppt\u00e4ckt och syntes av kvantprickar"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "3"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/che/2023",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 11000000,
#             "prizeAmountAdjusted": 11000000
#         },
#         {
#             "awardYear": "2022",
#             "category": {
#                 "en": "Physiology or Medicine",
#                 "no": "Fysiologi eller medisin",
#                 "se": "Fysiologi eller medicin"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Physiology or Medicine",
#                 "no": "Nobelprisen i fysiologi eller medisin",
#                 "se": "Nobelpriset i fysiologi eller medicin"
#             },
#             "dateAwarded": "2022-10-03",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Svante P\u00e4\u00e4bo"
#                     },
#                     "id": "1011",
#                     "knownName": {
#                         "en": "Svante P\u00e4\u00e4bo"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1011",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for his discoveries concerning the genomes of extinct hominins and human evolution",
#                         "se": "f\u00f6r hans uppt\u00e4ckter r\u00f6rande utd\u00f6da homininers arvsmassa och  m\u00e4nniskans evolution"
#                     },
#                     "portion": "1",
#                     "sortOrder": "1"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/med/2022",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 10000000,
#             "prizeAmountAdjusted": 10000000
#         },
#         {
#             "awardYear": "2022",
#             "category": {
#                 "en": "Physics",
#                 "no": "Fysikk",
#                 "se": "Fysik"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Physics",
#                 "no": "Nobelprisen i fysikk",
#                 "se": "Nobelpriset i fysik"
#             },
#             "dateAwarded": "2022-10-04",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Alain Aspect"
#                     },
#                     "id": "1012",
#                     "knownName": {
#                         "en": "Alain Aspect"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1012",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for experiments with entangled photons, establishing the violation of Bell inequalities and  pioneering quantum information science",
#                         "se": "f\u00f6r experiment med sammanf\u00e4tade fotoner som p\u00e5visat brott mot Bell-olikheter och  banat v\u00e4g f\u00f6r kvantinformationsvetenskap"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "1"
#                 },
#                 {
#                     "fullName": {
#                         "en": "John F. Clauser"
#                     },
#                     "id": "1013",
#                     "knownName": {
#                         "en": "John Clauser"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1013",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for experiments with entangled photons, establishing the violation of Bell inequalities and  pioneering quantum information science",
#                         "se": "f\u00f6r experiment med sammanf\u00e4tade fotoner som p\u00e5visat brott mot Bell-olikheter och  banat v\u00e4g f\u00f6r kvantinformationsvetenskap"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "2"
#                 },
#                 {
#                     "fullName": {
#                         "en": "Anton Zeilinger"
#                     },
#                     "id": "1014",
#                     "knownName": {
#                         "en": "Anton Zeilinger"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1014",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for experiments with entangled photons, establishing the violation of Bell inequalities and  pioneering quantum information science",
#                         "se": "f\u00f6r experiment med sammanf\u00e4tade fotoner som p\u00e5visat brott mot Bell-olikheter och  banat v\u00e4g f\u00f6r kvantinformationsvetenskap"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "3"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/phy/2022",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 10000000,
#             "prizeAmountAdjusted": 10000000
#         },
#         {
#             "awardYear": "2022",
#             "category": {
#                 "en": "Peace",
#                 "no": "Fred",
#                 "se": "Fred"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Peace Prize",
#                 "no": "Nobels fredspris",
#                 "se": "Nobels fredspris"
#             },
#             "dateAwarded": "2022-10-07",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Ales Bialiatski "
#                     },
#                     "id": "1018",
#                     "knownName": {
#                         "en": "Ales Bialiatski",
#                         "no": " Ales Bjaljatski"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1018",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "The Peace Prize laureates represent civil society in their home countries. They have for many years promoted the right to criticise power and protect the fundamental rights of citizens. They have made an outstanding effort to document war crimes, human right abuses and the abuse of power. Together they demonstrate the significance of civil society for peace and democracy.",
#                         "no": "Prisvinnerne representerer sivilsamfunnet i sine hjemland. De har i mange \u00e5r st\u00e5tt opp for retten til maktkritikk og grunnleggende rettigheter for borgerne. De har gjort en enest\u00e5ende innsats for \u00e5 dokumentere krigsforbrytelser, brudd p\u00e5 menneskerettigheter og maktmisbruk. Til sammen viser de sivilsamfunnets betydning for fred og demokrati."
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "1"
#                 },
#                 {
#                     "id": "1019",
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1019",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "The Peace Prize laureates represent civil society in their home countries. They have for many years promoted the right to criticise power and protect the fundamental rights of citizens. They have made an outstanding effort to document war crimes, human right abuses and the abuse of power. Together they demonstrate the significance of civil society for peace and democracy.",
#                         "no": "Prisvinnerne representerer sivilsamfunnet i sine hjemland. De har i mange \u00e5r st\u00e5tt opp for retten til maktkritikk og grunnleggende rettigheter for borgerne. De har gjort en enest\u00e5ende innsats for \u00e5 dokumentere krigsforbrytelser, brudd p\u00e5 menneskerettigheter og maktmisbruk. Til sammen viser de sivilsamfunnets betydning for fred og demokrati."
#                     },
#                     "orgName": {
#                         "en": "Memorial",
#                         "no": "Memorial"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "2"
#                 },
#                 {
#                     "id": "1020",
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1020",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "The Peace Prize laureates represent civil society in their home countries. They have for many years promoted the right to criticise power and protect the fundamental rights of citizens. They have made an outstanding effort to document war crimes, human right abuses and the abuse of power. Together they demonstrate the significance of civil society for peace and democracy.",
#                         "no": "Prisvinnerne representerer sivilsamfunnet i sine hjemland. De har i mange \u00e5r st\u00e5tt opp for retten til maktkritikk og grunnleggende rettigheter for borgerne. De har gjort en enest\u00e5ende innsats for \u00e5 dokumentere krigsforbrytelser, brudd p\u00e5 menneskerettigheter og maktmisbruk. Til sammen viser de sivilsamfunnets betydning for fred og demokrati."
#                     },
#                     "orgName": {
#                         "en": "Center for Civil Liberties",
#                         "no": "Senteret for sivile rettigheter"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "3"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/pea/2022",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 10000000,
#             "prizeAmountAdjusted": 10000000
#         },
#         {
#             "awardYear": "2022",
#             "category": {
#                 "en": "Literature",
#                 "no": "Litteratur",
#                 "se": "Litteratur"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Literature",
#                 "no": "Nobelprisen i litteratur",
#                 "se": "Nobelpriset i litteratur"
#             },
#             "dateAwarded": "2022-10-06",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Annie Ernaux"
#                     },
#                     "id": "1017",
#                     "knownName": {
#                         "en": "Annie Ernaux"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1017",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for the courage and clinical acuity with which she uncovers the roots, estrangements and  collective restraints of personal memory",
#                         "se": "f\u00f6r det mod och den kliniska sk\u00e4rpa varmed hon avt\u00e4cker det personliga minnets r\u00f6tter,  fr\u00e4mlingskap och kollektiva ramar"
#                     },
#                     "portion": "1",
#                     "sortOrder": "1"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/lit/2022",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 10000000,
#             "prizeAmountAdjusted": 10000000
#         },
#         {
#             "awardYear": "2022",
#             "category": {
#                 "en": "Economic Sciences",
#                 "no": "\u00d8konomi",
#                 "se": "Ekonomi"
#             },
#             "categoryFullName": {
#                 "en": "The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel",
#                 "no": "Sveriges Riksbanks pris i \u00f8konomisk vitenskap til minne om Alfred Nobel",
#                 "se": "Sveriges Riksbanks pris i ekonomisk vetenskap till Alfred Nobels minne"
#             },
#             "dateAwarded": "2011-10-10",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Ben S. Bernanke"
#                     },
#                     "id": "1021",
#                     "knownName": {
#                         "en": "Ben Bernanke"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1021",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for research on banks and financial crises",
#                         "se": "f\u00f6r forskning om banker och finanskriser"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "1"
#                 },
#                 {
#                     "fullName": {
#                         "en": "Douglas W. Diamond"
#                     },
#                     "id": "1022",
#                     "knownName": {
#                         "en": "Douglas Diamond"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1022",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for research on banks and financial crises",
#                         "se": "f\u00f6r forskning om banker och finanskriser"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "2"
#                 },
#                 {
#                     "fullName": {
#                         "en": "Philip H. Dybvig"
#                     },
#                     "id": "1023",
#                     "knownName": {
#                         "en": "Philip Dybvig"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1023",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for research on banks and financial crises",
#                         "se": "f\u00f6r forskning om banker och finanskriser"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "3"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/eco/2022",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 10000000,
#             "prizeAmountAdjusted": 10000000
#         },
#         {
#             "awardYear": "2022",
#             "category": {
#                 "en": "Chemistry",
#                 "no": "Kjemi",
#                 "se": "Kemi"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Chemistry",
#                 "no": "Nobelprisen i kjemi",
#                 "se": "Nobelpriset i kemi"
#             },
#             "dateAwarded": "2022-10-05",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Carolyn R. Bertozzi"
#                     },
#                     "id": "1015",
#                     "knownName": {
#                         "en": "Carolyn Bertozzi"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1015",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for the development of click chemistry and bioorthogonal chemistry",
#                         "se": "f\u00f6r utveckling av klickkemi och bioortogonal kemi"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "1"
#                 },
#                 {
#                     "fullName": {
#                         "en": "Morten Meldal"
#                     },
#                     "id": "1016",
#                     "knownName": {
#                         "en": "Morten Meldal"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1016",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for the development of click chemistry and bioorthogonal chemistry",
#                         "se": "f\u00f6r utveckling av klickkemi och bioortogonal kemi"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "2"
#                 },
#                 {
#                     "fullName": {
#                         "en": "K. Barry Sharpless"
#                     },
#                     "id": "743",
#                     "knownName": {
#                         "en": "K. Barry Sharpless"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/743",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for the development of click chemistry and bioorthogonal chemistry",
#                         "se": "f\u00f6r utveckling av klickkemi och bioortogonal kemi"
#                     },
#                     "portion": "1/3",
#                     "sortOrder": "3"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/che/2022",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 10000000,
#             "prizeAmountAdjusted": 10000000
#         },
#         {
#             "awardYear": "2021",
#             "category": {
#                 "en": "Physiology or Medicine",
#                 "no": "Fysiologi eller medisin",
#                 "se": "Fysiologi eller medicin"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Physiology or Medicine",
#                 "no": "Nobelprisen i fysiologi eller medisin",
#                 "se": "Nobelpriset i fysiologi eller medicin"
#             },
#             "dateAwarded": "2021-10-04",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "David Julius"
#                     },
#                     "id": "997",
#                     "knownName": {
#                         "en": "David Julius"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/997",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for their discoveries of receptors for temperature and touch"
#                     },
#                     "portion": "1/2",
#                     "sortOrder": "1"
#                 },
#                 {
#                     "fullName": {
#                         "en": "Ardem Patapoutian"
#                     },
#                     "id": "998",
#                     "knownName": {
#                         "en": "Ardem Patapoutian"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/998",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for their discoveries of receptors for temperature and touch"
#                     },
#                     "portion": "1/2",
#                     "sortOrder": "2"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/med/2021",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 10000000,
#             "prizeAmountAdjusted": 10836735
#         },
#         {
#             "awardYear": "2021",
#             "category": {
#                 "en": "Physics",
#                 "no": "Fysikk",
#                 "se": "Fysik"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Physics",
#                 "no": "Nobelprisen i fysikk",
#                 "se": "Nobelpriset i fysik"
#             },
#             "dateAwarded": "2021-10-05",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Syukuro Manabe"
#                     },
#                     "id": "999",
#                     "knownName": {
#                         "en": "Syukuro Manabe"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/999",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for the physical modelling of Earth\u2019s climate, quantifying variability and reliably predicting global warming"
#                     },
#                     "portion": "1/4",
#                     "sortOrder": "1"
#                 },
#                 {
#                     "fullName": {
#                         "en": "Klaus Hasselmann"
#                     },
#                     "id": "1000",
#                     "knownName": {
#                         "en": "Klaus Hasselmann"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1000",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for the physical modelling of Earth\u2019s climate, quantifying variability and reliably predicting global warming"
#                     },
#                     "portion": "1/4",
#                     "sortOrder": "2"
#                 },
#                 {
#                     "fullName": {
#                         "en": "Giorgio Parisi"
#                     },
#                     "id": "1001",
#                     "knownName": {
#                         "en": "Giorgio Parisi"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1001",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for the discovery of the interplay of disorder and fluctuations in physical systems from atomic to planetary scales"
#                     },
#                     "portion": "1/2",
#                     "sortOrder": "3"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/phy/2021",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 10000000,
#             "prizeAmountAdjusted": 10836735,
#             "topMotivation": {
#                 "en": "for groundbreaking contributions to our understanding of complex physical systems"
#             }
#         },
#         {
#             "awardYear": "2021",
#             "category": {
#                 "en": "Peace",
#                 "no": "Fred",
#                 "se": "Fred"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Peace Prize",
#                 "no": "Nobels fredspris",
#                 "se": "Nobels fredspris"
#             },
#             "dateAwarded": "2021-10-08",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Maria Ressa"
#                     },
#                     "id": "1005",
#                     "knownName": {
#                         "en": "Maria Ressa"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1005",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for their efforts to safeguard freedom of expression, which is a precondition for democracy and lasting peace",
#                         "no": "for deres innsats for ytringsfrihet, som er en forutsetning for demokrati og varig fred"
#                     },
#                     "portion": "1/2",
#                     "sortOrder": "1"
#                 },
#                 {
#                     "fullName": {
#                         "en": "Dmitry Andreyevich Muratov"
#                     },
#                     "id": "1006",
#                     "knownName": {
#                         "en": "Dmitry Muratov",
#                         "no": "Dmitrij Muratov"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1006",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for their efforts to safeguard freedom of expression, which is a precondition for democracy and lasting peace",
#                         "no": "for deres innsats for ytringsfrihet, som er en forutsetning for demokrati og varig fred"
#                     },
#                     "portion": "1/2",
#                     "sortOrder": "2"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/pea/2021",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 10000000,
#             "prizeAmountAdjusted": 10836735
#         },
#         {
#             "awardYear": "2021",
#             "category": {
#                 "en": "Literature",
#                 "no": "Litteratur",
#                 "se": "Litteratur"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Literature",
#                 "no": "Nobelprisen i litteratur",
#                 "se": "Nobelpriset i litteratur"
#             },
#             "dateAwarded": "2021-10-07",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Abdulrazak Gurnah"
#                     },
#                     "id": "1004",
#                     "knownName": {
#                         "en": "Abdulrazak Gurnah"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1004",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for his uncompromising and compassionate penetration of the effects of colonialism and the fate of the refugee in the gulf between cultures and continents"
#                     },
#                     "portion": "1",
#                     "sortOrder": "1"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/lit/2021",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 10000000,
#             "prizeAmountAdjusted": 10836735
#         },
#         {
#             "awardYear": "2021",
#             "category": {
#                 "en": "Economic Sciences",
#                 "no": "\u00d8konomi",
#                 "se": "Ekonomi"
#             },
#             "categoryFullName": {
#                 "en": "The Sveriges Riksbank Prize in Economic Sciences in Memory of Alfred Nobel",
#                 "no": "Sveriges Riksbanks pris i \u00f8konomisk vitenskap til minne om Alfred Nobel",
#                 "se": "Sveriges Riksbanks pris i ekonomisk vetenskap till Alfred Nobels minne"
#             },
#             "dateAwarded": "2021-10-11",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "David Card"
#                     },
#                     "id": "1007",
#                     "knownName": {
#                         "en": "David Card"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1007",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for his empirical contributions to labour economics"
#                     },
#                     "portion": "1/2",
#                     "sortOrder": "1"
#                 },
#                 {
#                     "fullName": {
#                         "en": "Joshua D. Angrist"
#                     },
#                     "id": "1008",
#                     "knownName": {
#                         "en": "Joshua D. Angrist"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1008",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
# ...
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for his eminently practical administration of the Inter-Parliamentary Union",
#                         "no": "for sin fremragende praktiske administrering av Den interparlamentariske union"
#                     },
#                     "portion": "1/2",
#                     "sortOrder": "2"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/pea/1902",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 141847,
#             "prizeAmountAdjusted": 9129789
#         },
#         {
#             "awardYear": "1902",
#             "category": {
#                 "en": "Literature",
#                 "no": "Litteratur",
#                 "se": "Litteratur"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Literature",
#                 "no": "Nobelprisen i litteratur",
#                 "se": "Nobelpriset i litteratur"
#             },
#             "dateAwarded": "1902-11-13",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Christian Matthias Theodor Mommsen"
#                     },
#                     "id": "571",
#                     "knownName": {
#                         "en": "Theodor Mommsen"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/571",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "the greatest living master of the art of historical writing, with special reference to his monumental work, <I>A history of Rome</I>",
#                         "se": "nutidens st\u00f6rste levande m\u00e4stare i den historiska framst\u00e4llningens konst, med s\u00e4rskilt f\u00e4st avseende \u00e5 hans monumentala verk R\u00f6mische Geschichte"
#                     },
#                     "portion": "1",
#                     "sortOrder": "1"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/lit/1902",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 141847,
#             "prizeAmountAdjusted": 9129789
#         },
#         {
#             "awardYear": "1902",
#             "category": {
#                 "en": "Chemistry",
#                 "no": "Kjemi",
#                 "se": "Kemi"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Chemistry",
#                 "no": "Nobelprisen i kjemi",
#                 "se": "Nobelpriset i kemi"
#             },
#             "dateAwarded": "1902-11-11",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Hermann Emil Fischer"
#                     },
#                     "id": "161",
#                     "knownName": {
#                         "en": "Emil Fischer"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/161",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "in recognition of the extraordinary services he has rendered by his work on sugar and purine syntheses",
#                         "se": "s\u00e5som ett erk\u00e4nnande av den utomordentliga f\u00f6rtj\u00e4nst han inlagt genom sina syntetiska arbeten inom socker - och purin-grupperna"
#                     },
#                     "portion": "1",
#                     "sortOrder": "1"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/che/1902",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 141847,
#             "prizeAmountAdjusted": 9129789
#         },
#         {
#             "awardYear": "1901",
#             "category": {
#                 "en": "Physiology or Medicine",
#                 "no": "Fysiologi eller medisin",
#                 "se": "Fysiologi eller medicin"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Physiology or Medicine",
#                 "no": "Nobelprisen i fysiologi eller medisin",
#                 "se": "Nobelpriset i fysiologi eller medicin"
#             },
#             "dateAwarded": "1901-10-30",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Emil Adolf von Behring"
#                     },
#                     "id": "293",
#                     "knownName": {
#                         "en": "Emil von Behring"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/293",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for his work on serum therapy, especially its application against diphtheria, by which he has opened a new road in the domain of medical science and thereby placed in the hands of the physician a victorious weapon against illness and deaths",
#                         "se": "f\u00f6r hans arbete r\u00f6rande serumterapien och s\u00e4rskilt dess anv\u00e4ndning mot difteri, varigenom han brutit en ny v\u00e4g inom den medicinska vetenskapens omr\u00e5de och givit l\u00e4karen ett segerrikt vapen i kampen mot sjukdom och d\u00f6d"
#                     },
#                     "portion": "1",
#                     "sortOrder": "1"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/med/1901",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 150782,
#             "prizeAmountAdjusted": 9704878
#         },
#         {
#             "awardYear": "1901",
#             "category": {
#                 "en": "Physics",
#                 "no": "Fysikk",
#                 "se": "Fysik"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Physics",
#                 "no": "Nobelprisen i fysikk",
#                 "se": "Nobelpriset i fysik"
#             },
#             "dateAwarded": "1901-11-12",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Wilhelm Conrad R\u00f6ntgen"
#                     },
#                     "id": "1",
#                     "knownName": {
#                         "en": "Wilhelm Conrad R\u00f6ntgen"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/1",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "in recognition of the extraordinary services he has rendered by the discovery of the remarkable rays subsequently named after him",
#                         "se": "s\u00e5som ett erk\u00e4nnande av den utomordentliga f\u00f6rtj\u00e4nst han inlagt genom uppt\u00e4ckten av de egendomliga str\u00e5lar, som sedermera uppkallats efter honom"
#                     },
#                     "portion": "1",
#                     "sortOrder": "1"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/phy/1901",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 150782,
#             "prizeAmountAdjusted": 9704878
#         },
#         {
#             "awardYear": "1901",
#             "category": {
#                 "en": "Peace",
#                 "no": "Fred",
#                 "se": "Fred"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Peace Prize",
#                 "no": "Nobels fredspris",
#                 "se": "Nobels fredspris"
#             },
#             "dateAwarded": "1901-12-10",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Jean Henry Dunant"
#                     },
#                     "id": "462",
#                     "knownName": {
#                         "en": "Henry Dunant"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/462",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for his humanitarian efforts to help wounded soldiers and create international understanding",
#                         "no": "for sin humanit\u00e6re innsats for \u00e5 hjelpe s\u00e5rede soldater og skape internasjonal forst\u00e5else"
#                     },
#                     "portion": "1/2",
#                     "sortOrder": "1"
#                 },
#                 {
#                     "fullName": {
#                         "en": "Fr\u00e9d\u00e9ric Passy"
#                     },
#                     "id": "463",
#                     "knownName": {
#                         "en": "Fr\u00e9d\u00e9ric Passy"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/463",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "for his lifelong work for international peace conferences, diplomacy and arbitration",
#                         "no": "for sin  livslange innsats for internasjonale fredskonferanser, diplomati og voldgift"
#                     },
#                     "portion": "1/2",
#                     "sortOrder": "2"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/pea/1901",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 150782,
#             "prizeAmountAdjusted": 9704878
#         },
#         {
#             "awardYear": "1901",
#             "category": {
#                 "en": "Literature",
#                 "no": "Litteratur",
#                 "se": "Litteratur"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Literature",
#                 "no": "Nobelprisen i litteratur",
#                 "se": "Nobelpriset i litteratur"
#             },
#             "dateAwarded": "1901-11-14",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Sully Prudhomme"
#                     },
#                     "id": "569",
#                     "knownName": {
#                         "en": "Sully Prudhomme"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/569",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "in special recognition of his poetic composition, which gives evidence of lofty idealism, artistic perfection and a rare combination of the qualities of both heart and intellect",
#                         "se": "s\u00e5som ett erk\u00e4nnande av hans utm\u00e4rkta, j\u00e4mv\u00e4l under senare \u00e5r \u00e5dagalagda f\u00f6rtj\u00e4nster som f\u00f6rfattare och s\u00e4rskilt av hans om h\u00f6g idealitet, konstn\u00e4rlig full\u00e4ndning samt s\u00e4llspord f\u00f6rening av hj\u00e4rtats och snillets egenskaper vittnande diktning"
#                     },
#                     "portion": "1",
#                     "sortOrder": "1"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/lit/1901",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 150782,
#             "prizeAmountAdjusted": 9704878
#         },
#         {
#             "awardYear": "1901",
#             "category": {
#                 "en": "Chemistry",
#                 "no": "Kjemi",
#                 "se": "Kemi"
#             },
#             "categoryFullName": {
#                 "en": "The Nobel Prize in Chemistry",
#                 "no": "Nobelprisen i kjemi",
#                 "se": "Nobelpriset i kemi"
#             },
#             "dateAwarded": "1901-11-12",
#             "laureates": [
#                 {
#                     "fullName": {
#                         "en": "Jacobus Henricus van 't Hoff"
#                     },
#                     "id": "160",
#                     "knownName": {
#                         "en": "Jacobus H. van 't Hoff"
#                     },
#                     "links": [
#                         {
#                             "action": "GET",
#                             "href": "https://api.nobelprize.org/2/laureate/160",
#                             "rel": "laureate",
#                             "types": "application/json"
#                         }
#                     ],
#                     "motivation": {
#                         "en": "in recognition of the extraordinary services he has rendered by the discovery of the laws of chemical dynamics and osmotic pressure in solutions",
#                         "se": "s\u00e5som ett erk\u00e4nnande av den utomordentliga f\u00f6rtj\u00e4nst han inlagt genom uppt\u00e4ckten av lagarna f\u00f6r den kemiska dynamiken och f\u00f6r det osmotiska trycket i l\u00f6sningar"
#                     },
#                     "portion": "1",
#                     "sortOrder": "1"
#                 }
#             ],
#             "links": [
#                 {
#                     "action": "GET",
#                     "href": "https://api.nobelprize.org/2/nobelPrize/che/1901",
#                     "rel": "nobelPrize",
#                     "types": "application/json"
#                 }
#             ],
#             "prizeAmount": 150782,
#             "prizeAmountAdjusted": 9704878
#         }
#     ]
# }

# %%
response["nobelPrizes"][5]
# Out:
# {'awardYear': '2022',
#  'category': {'en': 'Physiology or Medicine',
#   'no': 'Fysiologi eller medisin',
#   'se': 'Fysiologi eller medicin'},
#  'categoryFullName': {'en': 'The Nobel Prize in Physiology or Medicine',
#   'no': 'Nobelprisen i fysiologi eller medisin',
#   'se': 'Nobelpriset i fysiologi eller medicin'},
#  'dateAwarded': '2022-10-03',
#  'prizeAmount': 10000000,
#  'prizeAmountAdjusted': 10000000,
#  'links': [{'rel': 'nobelPrize',
#    'href': 'https://api.nobelprize.org/2/nobelPrize/med/2022',
#    'action': 'GET',
#    'types': 'application/json'}],
#  'laureates': [{'id': '1011',
#    'knownName': {'en': 'Svante Pääbo'},
#    'fullName': {'en': 'Svante Pääbo'},
#    'portion': '1',
#    'sortOrder': '1',
#    'motivation': {'en': 'for his discoveries concerning the genomes of extinct hominins and human evolution',
#     'se': 'för hans upptäckter rörande utdöda homininers arvsmassa och  människans evolution'},
#    'links': [{'rel': 'laureate',
#      'href': 'https://api.nobelprize.org/2/laureate/1011',
#      'action': 'GET',
#      'types': 'application/json'}]}]}

# %%
response["nobelPrizes"][5]["category"]["en"]
# Out:
# 'Physiology or Medicine'

# %%
response["meta"]
# Out:
# {'offset': 1,
#  'limit': 10000,
#  'nobelPrizeYear': 1901,
#  'yearTo': 2023,
#  'count': 670,
#  'terms': 'https://www.nobelprize.org/about/terms-of-use-for-api-nobelprize-org-and-data-nobelprize-org/',
#  'license': 'https://www.nobelprize.org/about/terms-of-use-for-api-nobelprize-org-and-data-nobelprize-org/#licence',
#  'disclaimer': 'https://www.nobelprize.org/about/terms-of-use-for-api-nobelprize-org-and-data-nobelprize-org/#disclaimer'}

# %%
response["prizes"][2]
# Out:
# {'year': '2023',
#  'category': 'literature',
#  'laureates': [{'id': '1032',
#    'firstname': 'Jon',
#    'surname': 'Fosse',
#    'motivation': '"for his innovative plays and prose which give voice to the unsayable"',
#    'share': '1'}]}

# %%
response["prizes"][101]
# Out:
# {'year': '2007',
#  'category': 'medicine',
#  'laureates': [{'id': '811',
#    'firstname': 'Mario R.',
#    'surname': 'Capecchi',
#    'motivation': '"for their discoveries of principles for introducing specific gene modifications in mice by the use of embryonic stem cells"',
#    'share': '3'},
#   {'id': '812',
#    'firstname': 'Sir Martin J.',
#    'surname': 'Evans',
#    'motivation': '"for their discoveries of principles for introducing specific gene modifications in mice by the use of embryonic stem cells"',
#    'share': '3'},
#   {'id': '813',
#    'firstname': 'Oliver',
#    'surname': 'Smithies',
#    'motivation': '"for their discoveries of principles for introducing specific gene modifications in mice by the use of embryonic stem cells"',
#    'share': '3'}]}

# %%
response["prizes"][99]
# Out:
# {'year': '2007',
#  'category': 'peace',
#  'laureates': [{'id': '818',
#    'motivation': '"for their efforts to build up and disseminate greater knowledge about man-made climate change, and to lay the foundations for the measures that are needed to counteract such change"',
#    'share': '2',
#    'firstname': 'Intergovernmental Panel on Climate Change'},
#   {'id': '819',
#    'firstname': 'Al',
#    'surname': 'Gore',
#    'motivation': '"for their efforts to build up and disseminate greater knowledge about man-made climate change, and to lay the foundations for the measures that are needed to counteract such change"',
#    'share': '2'}]}

# %%
response["prizes"][670]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/dejesusalcala/Documents/data_analytics_bootcamp/projects/nobel_peace_prize/code/analysis.ipynb Cell 11 line 1
# ----> <a href='vscode-notebook-cell:/Users/dejesusalcala/Documents/data_analytics_bootcamp/projects/nobel_peace_prize/code/analysis.ipynb#X15sZmlsZQ%3D%3D?line=0'>1</a> response["prizes"][670]
#
# IndexError: list index out of range

# %%
response["nobelPrizes"][1]["awardYear"]
# Out:
# '2023'

# %%
x = range(0,669)
x[668]
# Out:
# 668

# %%
x = [1,2,3]
y = [3,4,5]
df = pd.DataFrame({
    "x_name": x,
    "y_name": y
})
df
# Out:
#    x_name  y_name
# 0       1       3
# 1       2       4
# 2       3       5

# %%
res = response["nobelPrizes"][1]["awardYear"]

# %%
award_year = []
laureates = []
motivation = []
links =[]
category = []
name = []

for i in range(0,668):
    year = response["nobelPrizes"][i]["awardYear"]
    award_year.append(year)

    df = pd.dataframe({
        "": award_year,
        "": laureates)
        }
    )

# %%
award_year
# Out:
# ['2023',
#  '2023',
#  '2023',
#  '2023',
#  '2023',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2022',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2021',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2020',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2019',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2018',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2017',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2016',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2015',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2014',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2013',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2012',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2011',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2010',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2009',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2008',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2007',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2006',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2005',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2004',
#  '2003',
#  '2003',
#  '2003',
#  '2003',
#  '2003',
#  '2003',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2002',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2001',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '2000',
#  '1999',
#  '1999',
#  '1999',
#  '1999',
#  '1999',
#  '1999',
#  '1998',
#  '1998',
#  '1998',
#  '1998',
#  '1998',
#  '1998',
#  '1997',
#  '1997',
#  '1997',
#  '1997',
#  '1997',
#  '1997',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1996',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1995',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1994',
#  '1993',
#  '1993',
#  '1993',
#  '1993',
#  '1993',
#  '1993',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1992',
#  '1991',
#  '1991',
#  '1991',
#  '1991',
#  '1991',
#  '1991',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1990',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1989',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1988',
#  '1987',
#  '1987',
#  '1987',
#  '1987',
#  '1987',
#  '1987',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1986',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1985',
#  '1984',
#  '1984',
#  '1984',
#  '1984',
#  '1984',
#  '1984',
#  '1983',
#  '1983',
#  '1983',
#  '1983',
#  '1983',
#  '1983',
#  '1982',
#  '1982',
#  '1982',
#  '1982',
#  '1982',
#  '1982',
#  '1981',
#  '1981',
#  '1981',
#  '1981',
#  '1981',
#  '1981',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1980',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1979',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1978',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1977',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1976',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1975',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1974',
#  '1973',
#  '1973',
#  '1973',
#  '1973',
#  '1973',
#  '1973',
#  '1972',
#  '1972',
#  '1972',
#  '1972',
#  '1972',
#  '1972',
#  '1971',
#  '1971',
#  '1971',
#  '1971',
#  '1971',
#  '1971',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1970',
#  '1969',
#  '1969',
#  '1969',
#  '1969',
#  '1969',
#  '1969',
#  '1968',
#  '1968',
#  '1968',
#  '1968',
#  '1968',
#  '1967',
#  '1967',
#  '1967',
#  '1967',
#  '1967',
#  '1966',
#  '1966',
#  '1966',
#  '1966',
#  '1966',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '1965',
#  '1964',
#  '1964',
#  '1964',
#  '1964',
#  '1964',
#  '1963',
#  '1963',
#  '1963',
#  '1963',
#  '1963',
#  '1962',
#  '1962',
#  '1962',
#  '1962',
#  '1962',
#  '1961',
#  '1961',
#  '1961',
#  '1961',
#  '1961',
#  '1960',
#  '1960',
#  '1960',
#  '1960',
#  '1960',
#  '1959',
#  '1959',
#  '1959',
#  '1959',
#  '1959',
#  '1958',
#  '1958',
#  '1958',
#  '1958',
#  '1958',
#  '1957',
#  '1957',
#  '1957',
#  '1957',
#  '1957',
#  '1956',
#  '1956',
#  '1956',
#  '1956',
#  '1956',
#  '1955',
#  '1955',
#  '1955',
#  '1955',
#  '1955',
#  '1954',
#  '1954',
#  '1954',
#  '1954',
#  '1954',
#  '1953',
#  '1953',
#  '1953',
#  '1953',
#  '1953',
#  '1952',
#  '1952',
#  '1952',
#  '1952',
#  '1952',
#  '1951',
#  '1951',
#  '1951',
#  '1951',
#  '1951',
#  '1950',
#  '1950',
#  '1950',
#  '1950',
#  '1950',
#  '1949',
#  '1949',
#  '1949',
#  '1949',
#  '1949',
#  '1948',
#  '1948',
#  '1948',
#  '1948',
#  '1948',
#  '1947',
#  '1947',
#  '1947',
#  '1947',
#  '1947',
#  '1946',
#  '1946',
#  '1946',
#  '1946',
#  '1946',
#  '1945',
#  '1945',
#  '1945',
#  '1945',
#  '1945',
#  '1944',
#  '1944',
#  '1944',
#  '1944',
#  '1944',
#  '1943',
#  '1943',
#  '1943',
#  '1943',
#  '1943',
#  '1942',
#  '1942',
#  '1942',
#  '1942',
#  '1942',
#  '1941',
#  '1941',
#  '1941',
#  '1941',
#  '1941',
#  '1940',
#  '1940',
#  '1940',
#  '1940',
#  '1940',
#  '1939',
#  '1939',
#  '1939',
#  '1939',
#  '1939',
#  '1938',
#  '1938',
#  '1938',
#  '1938',
#  '1938',
#  '1937',
#  '1937',
#  '1937',
#  '1937',
#  '1937',
#  '1936',
#  '1936',
#  '1936',
#  '1936',
#  '1936',
#  '1935',
#  '1935',
#  '1935',
#  '1935',
#  '1935',
#  '1934',
#  '1934',
#  '1934',
#  '1934',
#  '1934',
#  '1933',
#  '1933',
#  '1933',
#  '1933',
#  '1933',
#  '1932',
#  '1932',
#  '1932',
#  '1932',
#  '1932',
#  '1931',
#  '1931',
#  '1931',
#  '1931',
#  '1931',
#  '1930',
#  '1930',
#  '1930',
#  '1930',
#  '1930',
#  '1929',
#  '1929',
#  '1929',
#  '1929',
#  '1929',
#  '1928',
#  '1928',
#  '1928',
#  '1928',
#  '1928',
#  '1927',
#  '1927',
#  '1927',
#  '1927',
#  '1927',
#  '1926',
#  '1926',
#  '1926',
#  '1926',
#  '1926',
#  '1925',
#  '1925',
#  '1925',
#  '1925',
#  '1925',
#  '1924',
#  '1924',
#  '1924',
#  '1924',
#  '1924',
#  '1923',
#  '1923',
#  '1923',
#  '1923',
#  '1923',
#  '1922',
#  '1922',
#  '1922',
#  '1922',
#  '1922',
#  '1921',
#  '1921',
#  '1921',
#  '1921',
#  '1921',
#  '1920',
#  '1920',
#  '1920',
#  '1920',
#  '1920',
#  '1919',
#  '1919',
#  '1919',
#  '1919',
#  '1919',
#  '1918',
#  '1918',
#  '1918',
#  '1918',
#  '1918',
#  '1917',
#  '1917',
#  '1917',
#  '1917',
#  '1917',
#  '1916',
#  '1916',
#  '1916',
#  '1916',
#  '1916',
#  '1915',
#  '1915',
#  '1915',
#  '1915',
#  '1915',
#  '1914',
#  '1914',
#  '1914',
#  '1914',
#  '1914',
#  '1913',
#  '1913',
#  '1913',
#  '1913',
#  '1913',
#  '1912',
#  '1912',
#  '1912',
#  '1912',
#  '1912',
#  '1911',
#  '1911',
#  '1911',
#  '1911',
#  '1911',
#  '1910',
#  '1910',
#  '1910',
#  '1910',
#  '1910',
#  '1909',
#  '1909',
#  '1909',
#  '1909',
#  '1909',
#  '1908',
#  '1908',
#  '1908',
#  '1908',
#  '1908',
#  '1907',
#  '1907',
#  '1907',
#  '1907',
#  '1907',
#  '1906',
#  '1906',
#  '1906',
#  '1906',
#  '1906',
#  '1905',
#  '1905',
#  '1905',
#  '1905',
#  '1905',
#  '1904',
#  '1904',
#  '1904',
#  '1904',
#  '1904',
#  '1903',
#  '1903',
#  '1903',
#  '1903',
#  '1903',
#  '1902',
#  '1902',
#  '1902',
#  '1902',
#  '1902',
#  '1901',
#  '1901',
#  '1901',
#  '1901']
